# %%
import pandas as pd

# %%
with open('../cmu_indic_pan_amp/etc/txt.done.data', encoding='utf-8') as file:
    text = file.readlines()
    print(text)
# Out:
# ['( pa_00321 "ਇਸ ਨੂੰ ਤਿੰਨ ਪ੍ਰਮੁੱਖ ਵਰਗਾ ਵਿੱਚ ਵੰਡਿਆ ਜਾਂਦਾ ਹੈ ." )\n', '( pa_00322 "ਇਹ ਕਹਾਣੀ , ਡਾਡਸਨ ਦੇ ਦੋਸਤਾਂ ਦੇ ਸੰਕੇਤਾਂ ਨਾਲ ਭਰੀ ਹੈ ." )\n', '( pa_00323 "ਓਲੰਪਿਕ ਖੇਡਾਂ ਹਰ ਚਾਰ ਸਾਲਾਂ ਬਾਅਦ ਹੁੰਦੀਆਂ ਹਨ ." )\n', '( pa_00324 "ਇਸ ਪ੍ਰਕਾਰ ਅਸੀ ਵੇਖਦੇ ਹਾਂ ਕਿ ਊਰਜਾ ਕਈ ਰੂਪਾਂ ਵਿੱਚ ਪਾਈ ਜਾਂਦੀ ਹੈ ." )\n', '( pa_00325 "ਆਧੁਨਿਕ ਇਟਲੀ ਰਾਜ ਦੇ ਰੂਪ ਵਿੱਚ ਸੰਗਠਿਤ ਹੋਇਆ ਸੀ ." )\n', '( pa_00326 "ਪਰ ਉਨ੍ਹਾ ਦੋਹਾਂ ਦਾ ਆਪਸੀ ਰਿਸ਼ਤਾ ਕਾਫ਼ੀ ਗੁੰਝਲਦਾਰ ਸੀ ." )\n', '( pa_00327 "ਪੜ੍ਹਨਾ ਵੀ ਉਸਦਾ ਬਹੁਤ ਘੱਟ ਹੋ ਗਿਆ ਸੀ ." )\n', '( pa_00328 "ਪਰ ਉਹ ਇੱਥੇ ਹੀ ਸੀ ." )\n', '( pa_00329 "ਪਰ ਹੁਣ ਜਿਹੜੀ ਨਵੀਂ ਪਰਿਭਾਸ਼ਾ ਸਾਹਮਣੇ ਆਈ ਹੈ, ਉਹ ਕਬੀਲੇ ਦੇ ਗੁਣਾਂ ਤੇ ਸਹੀ ਚਾਨਣ ਪਾਉਂਦੀ ਹੈ ." )\n', '( pa_00330 "ਜਦੋਂ ਉਨ੍ਹਾਂ ਦੀ ਉਮਰ ਚਾਰ ਸਾਲ ਸੀ ਤਾਂ ਉਨ੍ਹਾਂ ਦੇ ਮਾਤਾ ਪਿਤਾ ਅਮਰੀਕਾ ਰਹਿਣ ਆ ਗਏ ." )\n', '( pa_00331 "ਮੈਨੂੰ ਪਤਾ ਵੀ ਨਹੀਂ ਸੀ ." )\n', '( pa_00332 "ਮਗਰ ਅਸੀਂ ਉਸ ਨਾਲ ਫੌਜੀ ਬਾਰੇ ਕਿਸੇ ਕਿਸਮ ਦਾ ਜ਼ਿਕਰ ਨਾ ਕਰਦੇ ." )\n', '( pa_00333 "ਉਹਨੂੰ ਵਿਸ਼ਵਾਸ ਹੋ ਚੁੱਕਿਆ ਸੀ ਕਿ ਉਹ ਕੁੱਤੇ ਨੂੰ ਮਾਰ ਨਹੀਂ ਸਕਦਾ ." )\n', '( pa_00334 "ਰਹੀ ਗੱਲ ਕੁੜੀ ਦੀ, ਤਾਂ ਜਨਾਨੀਆਂ ਤੋਂ ਪੁਛੋ." )\n', '( pa_00335 "ਤਿੰਨ ਇੰਚ ਗਹਿਰਾ ਵੀ ਅਤੇ ਤਿੰਨ ਫੁੱਟ ਵੀ ." )\n', '( pa_00336 "ਯਾਦ ਰਹੇ ਕਿ ਮੈਗਨੀਟਿਊਡ ਦੀ ਗਿਣਤੀ ਜਿੰਨੀ ਜ਼ਿਆਦਾ ਹੁੰਦੀ ਹੈ ਤਾਰੇ ਦੀ ਚਾਨਣ ਓਨੀ ਹੀ ਘੱਟ ਹੁੰਦੀ ਹੈ ." )\n', '( pa_00337 "ਖਾਣ ਦਾ ਉਸਨੂੰ ਸਮਾਂ ਹੀ ਨਹੀਂ ਮਿਲ ਪਾਇਆ ." )\n', '( pa_00338 "ਉਸਦੇ ਦੋਨੋਂ ਹੱਥ ਅਤੇ ਉਂਗਲੀਆਂ ਪੂਰੀ ਤਰ੍ਹਾਂ ਸੁੰਨ ਹਨ ." )\n', '( pa_00339 "ਇਹ ਨਾਵਲ ਇਕ ਔਰਤ ਦੇ ਮਾਸ ਖਾਣਾ ਛੱਡਣ ਉਤੇ ਆਧਾਰਿਤ ਹੈ ." )\n', '( pa_00340 "ਇਸਤੋਂ ਬਾਅਦ ਇਸ ਪਾਣੀ ਨੂੰ ਕਪਾਹ ਦੇ ਕੱਪੜੇ ਵਿੱਚੋਂ ਕੱਢਿਆ ਜਾਂਦਾ ਹੈ ." )\n', '( pa_00341 "ਸ਼ਾਗਿਰਦੀ , ਇੱਕ ਸਿਖਲਾਈ ਦੀ ਪ੍ਰਣਾਲੀ ਹੈ ." )\n', '( pa_00342 "ਇਸ ਨੂੰ ਸ਼ੁਰੂ ਕਰਨ ਵਾਲੇ ਪਦਾਰਥ ਤੋਂ ਬਚਣ ਦੀ ਸਿਫਾਰਸ਼ ਕੀਤੀ ਜਾਂਦੀ ਹੈ ." )\n', '( pa_00343 "ਕੰਪਿਊਟਰ ਪ੍ਰੋਗਰਾਮਿੰਗ ਭਾਸ਼ਾ ਦੇ ਵਿਕਾਸ ਦਾ ਇਹ ਅਗਲਾ ਕਦਮ ਸੀ ." )\n', '( pa_00344 "ਮੈਗਜ਼ੀਨ ਦੇ ਉਸ ਵਕਤ ਦੇ ਰੂਸ ਵਿੱਚ ਕਾਫੀ ਪਾਠਕ ਸਨ ." )\n', '( pa_00345 "ਇਸ ਵਿੱਚ ਬਹੁਤ ਜਿਆਦਾ ਬਦਲਾਵ ਪਾਇਆ ਜਾਂਦਾ ਹੈ ." )\n', '( pa_00346 "ਪਿਛਲੇ ਕੁੱਝ ਸਾਲਾਂ ਵਿੱਚ ਉੱਚ ਸਿੱਖਿਆ ਦੇ ਖੇਤਰ ਵਿੱਚ ਬਹੁਤ ਜਿਆਦਾ ਵਿਕਾਸ ਹੋਇਆ ਹੈ ." )\n', '( pa_00347 "ਬਾਕੀ ਘਰ ਦੇ ਸਭ ਲੋਕ ਸਨ ." )\n', '( pa_00348 "ਇਹ ਢਾਂਚਾ ਖੇੜਾ ਦਾ ਹੀ ਹੈ, ਜੋ ਪਿੰਡ ਦੇ ਲੋਕਾਂ ਦੀ ਬਿਮਾਰੀਆਂ ਤੋ ਰੱਖਿਆ ਕਰਦਾ ਹੈ ." )\n', '( pa_00349 "ਇਸ ਦੇ ਬਾਅਦ ਉਹ ਲੰਡਨ ਗਏ ." )\n', '( pa_00350 "ਮੇਂ ਤੁਹਾਡੀ ਕੀ ਮਦਦ ਕਰ ਸਕਦਾ ਹਾਂ ." )\n', '( pa_00351 "ਇਸ ਲਈ ਅਸੀਂ ਚੁੱਪ ਰਹੇ ." )\n', '( pa_00352 "ਮਗਰ ਥੋੜੀ ਦੇਰ ਬਾਦ ਉਹ ਫਿਰ ਉਨ੍ਹਾਂ ਨਾਲ ਸ਼ਾਮਿਲ ਹੋ ਜਾਂਦਾ ." )\n', '( pa_00353 "ਇੱਕ ਪਲ ਨੂੰ ਉਹ ਭੁੱਲ ਗਿਆ ਕਿ ਉਹ ਬਰਫ ਨਾਲ ਪੂਰੀ ਤਰ੍ਹਾਂ ਜੰਮ ਚੁੱਕੀਆਂ ਹਨ ." )\n', '( pa_00354 "ਮੇਰੀ ਕਿਸੇ ਨਾ ਸੁਣੀ ." )\n', '( pa_00355 "ਅਤੇ ਇਸੇ ਤਰਾਂ ਐਂਟੀਕੁਆਰਕ ਉਲਟਾ ਰੰਗ ਰੱਖਦੇ ਹਨ ." )\n', '( pa_00356 "ਇਹ ਕੋਈ ਵਿਸ਼ੇਸ਼ ਚਿੰਤਾ ਦੀ ਗੱਲ ਨਹੀਂ ਸੀ ." )\n', '( pa_00357 "ਸਾਨੂੰ ਤੁਹਾਡੀ ਲੋੜ ਹੈ ." )\n', '( pa_00358 "ਮਾਰਕਸ ਅਤੇ ਏਂਗਲਜ਼ ਦੇ ਕਈ ਦੋਸਤ ਵੀ ਇਸ ਸੰਗਠਨ ਵਿੱਚ ਸ਼ਾਮਿਲ ਹੋ ਗਏ ." )\n', '( pa_00359 "ਇਹ ਪਹਿਲੀ ਵਾਰ ਸੀ, ਜਦੋਂ ਕਿਸੇ ਸਾਬਕਾ ਖਿਡਾਰੀ ਨੂੰ ਓਲੰਪਿਕ ਖੇਡਾਂ ਵਿੱਚ ਦਲ ਦਾ ਮੁਖੀ ਬਣਾਇਆ ਗਿਆ ਹੋਵੇ ." )\n', '( pa_00360 "ਪਹਿਲਾਂ ਆਲ ਇੰਡੀਆ ਰੇਡੀਓ ਲਾਹੌਰ ਤੋਂ ਗਾਣੇ ਗਾਉਣ ਦਾ ਮੌਕਾ ਮਿਲਿਆ ." )\n', '( pa_00361 "ਕਰਤਾਰ ਸਿੰਘ ਸਰਾਭਾ ਨੇ ਮੁੱਢਲੀ ਵਿੱਦਿਆ ਸਰਾਭਾ ਪਿੰਡ ਵਿੱਚ ਹੀ ਪ੍ਰਾਪਤ ਕੀਤੀ ." )\n', '( pa_00362 "ਉੱਚ ਪੱਧਰ ਪ੍ਰੋਗਰਾਮਿੰਗ ਭਾਸ਼ਾ ਕੰਪਿਊਟਰ ਮਸ਼ੀਨ ਉੱਤੇ ਨਿਰਭਰ ਨਹੀ ਕਰਦੀ ." )\n', '( pa_00363 "ਤੋਂ ਕਿਸੇ ਘਟਨਾ ਦਾ ਕੋਈ ਪ੍ਰਭਾਵ ਕਿਸੇ ਹੋਰ ਸਥਾਨ ਤੇ ਪ੍ਰਕਾਸ਼ ਤੋਂ ਪਹਿਲਾਂ ਨਹੀਂ ਪਹੁੰਚ ਸਕਦਾ ." )\n', '( pa_00364 "ਸਾਰਾ ਭਾਗ ਪਹਾੜੀ ਅਤੇ ਔਖਾ ਹੈ ." )\n', '( pa_00365 "ਪੱਛਮ ਦੇ ਨਾਟਕ \'ਸ਼ਾਸਤਰ ਵਿੱਚ ਦਵੰਦ\' ਉੱਤੇ ਬਹੁਤ ਜ਼ੋਰ ਦਿੱਤਾ ਗਿਆ ਹੈ ." )\n', '( pa_00366 "ਉਨ੍ਹਾਂ ਨੂੰ ਬਨਾਰਸ ਹਿੰਦੂ ਯੂਨੀਵਰਸਿਟੀ ਵੱਲੋਂ ਮਾਣਹਿਤ ਡਿਗਰੀ ਮਿਲੀ ." )\n', '( pa_00367 "ਹੁਣ ਟੈਗੋਰ ਦੇ ਜੀਵਨ ਦੇ ਕੁਝ ਮਹੀਨੇ ਹੀ ਬਚੇ ਸਨ ਪਰ ਕਵਿਤਾ ਹਾਲੇ ਵੀ ਉਸਦੇ ਅੰਦਰ ਜਵਾਨ ਸੀ ." )\n', '( pa_00368 "ਜਿਸ ਰੁੱਖ ਨੂੰ ਇਹ ਆਪਣਾ ਆਧਾਰ ਬਣਾਉਂਦੀ ਹੈ, ਉਸ ਦੇ ਗੁਣ ਵੀ ਇਸ ਵਿੱਚ ਸਮਾ ਜਾਂਦੇ ਹਨ ." )\n', '( pa_00369 "ਰੀਤਾਂ ਹਰ ਕਾਲਜ ਦੀਆਂ ਵੱਖਰੀਆਂ ਨੇਂ ." )\n', '( pa_00370 "ਉਹ ਇਸ ਨਦੀ ਨੂੰ ਜਾਣਦਾ ਸੀ ਕਿ ਉਹ ਤਲ ਤੱਕ ਜੰਮੀ ਸੀ ." )\n', '( pa_00371 "ਉਂਗਲੀਆਂ ਉਸਨੂੰ ਆਪਣੇ ਸਰੀਰ ਤੋਂ ਵੱਖ ਲੱਗ ਰਹੀਆਂ ਸਨ ." )\n', '( pa_00372 "ਵਿਆਹ ਉਪਰੰਤ ਪੈਦਾ ਹੋਈ ਔਲਾਦ ਨੂੰ ਨੀਵੀਂ ਕੁਲ ਵਾਲੀ ਸਮਝਿਆ ਗਿਆ ." )\n', '( pa_00373 "ਉਹ ਦੇਹ ਤੋਂ ਵੱਖ ਉਨ੍ਹਾਂ ਮੁੰਡਿਆਂ ਦੇ ਨਾਲ ਖੜਾ ਆਪਣੀ ਦੇਹ ਨੂੰ ਬਰਫ ਵਿੱਚ ਵੇਖ ਰਿਹਾ ਸੀ ." )\n', '( pa_00374 "ਉਨ੍ਹਾਂ ਨੇ ਪੰਜਾਬੀ ਵਿੱਚ ਆਪਣੀ ਐਮ ਏ ਪੰਜਾਬੀ ਯੂਨੀਵਰਸਿਟੀ ਤੋਂ ਕੀਤੀ ." )\n', '( pa_00375 "ਜੱਜ ਨੇ ਊਧਮ ਸਿੰਘ ਨੂੰ ਮੌਤ ਦੀ ਸਜ਼ਾ ਸੁਣਾ ਦਿੱਤੀ ." )\n', '( pa_00376 "ਉੱਚੇ ਪੱਛਮ ਵਿੱਚ ਵੀ ਸਮਰੱਥ ਵਰਖਾ ਹੁੰਦੀ ਹੈ ." )\n', '( pa_00377 "ਹੇਠ ...

# %%
cleaned_text = []
lines = []

for local_text in text:
    local_text = local_text.strip()
    local_text = local_text.split(' ')
    local_text = local_text[1:-1]
    filename = local_text[0]
    local_text = local_text[1:]
    content = " ".join(local_text)[1:-1]
    one_line = filename + '|' + content + '|' + content
    lines.append(one_line)

# %%
with open('metadata.csv', mode='w+', encoding='utf-8') as file:
    file.writelines("\n".join(lines))
